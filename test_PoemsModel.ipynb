# %% [markdown]
# ## Compile model

# %%
from poems_model import PoemsModel
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Slow version of gensim.models.doc2vec is being used

# %%
pm = PoemsModel()

poems_file = 'poems_33000.txt'
w2v_file = 'c:/data/ruscorpora_1_300_10.bin.gz'
pm.compile(poems_file, w2v_file)
# Out:
# poem count: 33712
# making word bags...
# Parse(word='недоена', tag=OpencorporaTag('UNKN'), normal_form='недоена', score=0.5, methods_stack=((<UnknAnalyzer>, 'ена'), (<KnownPrefixAnalyzer>, 'недо')))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='йа', tag=OpencorporaTag('UNKN'), normal_form='йа', score=1.0, methods_stack=((<UnknAnalyzer>, 'йа'),))
# Parse(word='йа', tag=OpencorporaTag('UNKN'), normal_form='йа', score=1.0, methods_stack=((<UnknAnalyzer>, 'йа'),))
# Parse(word='чау', tag=OpencorporaTag('UNKN'), normal_form='чау', score=1.0, methods_stack=((<UnknAnalyzer>, 'чау'),))
# Parse(word='чау', tag=OpencorporaTag('UNKN'), normal_form='чау', score=1.0, methods_stack=((<UnknAnalyzer>, 'чау'),))
# Parse(word='каа', tag=OpencorporaTag('UNKN'), normal_form='каа', score=1.0, methods_stack=((<UnknAnalyzer>, 'каа'),))
# Parse(word='щай', tag=OpencorporaTag('UNKN'), normal_form='щай', score=1.0, methods_stack=((<UnknAnalyzer>, 'щай'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='чау', tag=OpencorporaTag('UNKN'), normal_form='чау', score=1.0, methods_stack=((<UnknAnalyzer>, 'чау'),))
# Parse(word='чау', tag=OpencorporaTag('UNKN'), normal_form='чау', score=1.0, methods_stack=((<UnknAnalyzer>, 'чау'),))
# Parse(word='энд', tag=OpencorporaTag('UNKN'), normal_form='энд', score=1.0, methods_stack=((<UnknAnalyzer>, 'энд'),))
# Parse(word='адъ', tag=OpencorporaTag('UNKN'), normal_form='адъ', score=1.0, methods_stack=((<UnknAnalyzer>, 'адъ'),))
# Parse(word='шо', tag=OpencorporaTag('UNKN'), normal_form='шо', score=1.0, methods_stack=((<UnknAnalyzer>, 'шо'),))
# Parse(word='цэ', tag=OpencorporaTag('UNKN'), normal_form='цэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'цэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='кря', tag=OpencorporaTag('UNKN'), normal_form='кря', score=1.0, methods_stack=((<UnknAnalyzer>, 'кря'),))
# Parse(word='з', tag=OpencorporaTag('UNKN'), normal_form='з', score=1.0, methods_stack=((<UnknAnalyzer>, 'з'),))
# Parse(word='нэн', tag=OpencorporaTag('UNKN'), normal_form='нэн', score=1.0, methods_stack=((<UnknAnalyzer>, 'нэн'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='вий', tag=OpencorporaTag('UNKN'), normal_form='вий', score=1.0, methods_stack=((<UnknAnalyzer>, 'вий'),))
# Parse(word='еси', tag=OpencorporaTag('UNKN'), normal_form='еси', score=1.0, methods_stack=((<UnknAnalyzer>, 'еси'),))
# Parse(word='гэ', tag=OpencorporaTag('UNKN'), normal_form='гэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'гэ'),))
# Parse(word='би', tag=OpencorporaTag('UNKN'), normal_form='би', score=1.0, methods_stack=((<UnknAnalyzer>, 'би'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='се', tag=OpencorporaTag('UNKN'), normal_form='се', score=1.0, methods_stack=((<UnknAnalyzer>, 'се'),))
# Parse(word='се', tag=OpencorporaTag('UNKN'), normal_form='се', score=1.0, methods_stack=((<UnknAnalyzer>, 'се'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='вип', tag=OpencorporaTag('UNKN'), normal_form='вип', score=1.0, methods_stack=((<UnknAnalyzer>, 'вип'),))
# Parse(word='рёк', tag=OpencorporaTag('UNKN'), normal_form='рёк', score=1.0, methods_stack=((<UnknAnalyzer>, 'рёк'),))
# Parse(word='ор', tag=OpencorporaTag('UNKN'), normal_form='ор', score=1.0, methods_stack=((<UnknAnalyzer>, 'ор'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='зна', tag=OpencorporaTag('UNKN'), normal_form='зна', score=1.0, methods_stack=((<UnknAnalyzer>, 'зна'),))
# Parse(word='чит', tag=OpencorporaTag('UNKN'), normal_form='чит', score=1.0, methods_stack=((<UnknAnalyzer>, 'чит'),))
# Parse(word='нъю', tag=OpencorporaTag('UNKN'), normal_form='нъю', score=1.0, methods_stack=((<UnknAnalyzer>, 'нъю'),))
# Parse(word='нъю', tag=OpencorporaTag('UNKN'), normal_form='нъю', score=1.0, methods_stack=((<UnknAnalyzer>, 'нъю'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='ма', tag=OpencorporaTag('UNKN'), normal_form='ма', score=1.0, methods_stack=((<UnknAnalyzer>, 'ма'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='дё', tag=OpencorporaTag('UNKN'), normal_form='дё', score=1.0, methods_stack=((<UnknAnalyzer>, 'дё'),))
# Parse(word='эл', tag=OpencorporaTag('UNKN'), normal_form='эл', score=1.0, methods_stack=((<UnknAnalyzer>, 'эл'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='ня', tag=OpencorporaTag('UNKN'), normal_form='ня', score=1.0, methods_stack=((<UnknAnalyzer>, 'ня'),))
# Parse(word='заека', tag=OpencorporaTag('UNKN'), normal_form='заека', score=1.0, methods_stack=((<UnknAnalyzer>, 'ека'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='залка', tag=OpencorporaTag('UNKN'), normal_form='залка', score=1.0, methods_stack=((<UnknAnalyzer>, 'лка'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='чоб', tag=OpencorporaTag('UNKN'), normal_form='чоб', score=1.0, methods_stack=((<UnknAnalyzer>, 'чоб'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='тла', tag=OpencorporaTag('UNKN'), normal_form='тла', score=1.0, methods_stack=((<UnknAnalyzer>, 'тла'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='зая', tag=OpencorporaTag('UNKN'), normal_form='зая', score=1.0, methods_stack=((<UnknAnalyzer>, 'зая'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='джа', tag=OpencorporaTag('UNKN'), normal_form='джа', score=1.0, methods_stack=((<UnknAnalyzer>, 'джа'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='кыс', tag=OpencorporaTag('UNKN'), normal_form='кыс', score=1.0, methods_stack=((<UnknAnalyzer>, 'кыс'),))
# Parse(word='кыс', tag=OpencorporaTag('UNKN'), normal_form='кыс', score=1.0, methods_stack=((<UnknAnalyzer>, 'кыс'),))
# Parse(word='кыс', tag=OpencorporaTag('UNKN'), normal_form='кыс', score=1.0, methods_stack=((<UnknAnalyzer>, 'кыс'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='гуш', tag=OpencorporaTag('UNKN'), normal_form='гуш', score=1.0, methods_stack=((<UnknAnalyzer>, 'гуш'),))
# Parse(word='нелья', tag=OpencorporaTag('UNKN'), normal_form='нелья', score=1.0, methods_stack=((<UnknAnalyzer>, 'лья'), (<KnownPrefixAnalyzer>, 'не')))
# Parse(word='чук', tag=OpencorporaTag('UNKN'), normal_form='чук', score=1.0, methods_stack=((<UnknAnalyzer>, 'чук'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='залле', tag=OpencorporaTag('UNKN'), normal_form='залле', score=1.0, methods_stack=((<UnknAnalyzer>, 'лле'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='шэ', tag=OpencorporaTag('UNKN'), normal_form='шэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'шэ'),))
# Parse(word='кэ', tag=OpencorporaTag('UNKN'), normal_form='кэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'кэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='жог', tag=OpencorporaTag('UNKN'), normal_form='жог', score=1.0, methods_stack=((<UnknAnalyzer>, 'жог'),))
# Parse(word='сэн', tag=OpencorporaTag('UNKN'), normal_form='сэн', score=1.0, methods_stack=((<UnknAnalyzer>, 'сэн'),))
# Parse(word='иш', tag=OpencorporaTag('UNKN'), normal_form='иш', score=1.0, methods_stack=((<UnknAnalyzer>, 'иш'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='нэ', tag=OpencorporaTag('UNKN'), normal_form='нэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'нэ'),))
# Parse(word='ожи', tag=OpencorporaTag('UNKN'), normal_form='ожи', score=1.0, methods_stack=((<UnknAnalyzer>, 'ожи'),))
# Parse(word='обс', tag=OpencorporaTag('UNKN'), normal_form='обс', score=1.0, methods_stack=((<UnknAnalyzer>, 'обс'),))
# Parse(word='ные', tag=OpencorporaTag('UNKN'), normal_form='ные', score=1.0, methods_stack=((<UnknAnalyzer>, 'ные'),))
# Parse(word='тве', tag=OpencorporaTag('UNKN'), normal_form='тве', score=1.0, methods_stack=((<UnknAnalyzer>, 'тве'),))
# Parse(word='ете', tag=OpencorporaTag('UNKN'), normal_form='ете', score=1.0, methods_stack=((<UnknAnalyzer>, 'ете'),))
# Parse(word='пы', tag=OpencorporaTag('UNKN'), normal_form='пы', score=1.0, methods_stack=((<UnknAnalyzer>, 'пы'),))
# Parse(word='мав', tag=OpencorporaTag('UNKN'), normal_form='мав', score=1.0, methods_stack=((<UnknAnalyzer>, 'мав'),))
# Parse(word='бюь', tag=OpencorporaTag('UNKN'), normal_form='бюь', score=1.0, methods_stack=((<UnknAnalyzer>, 'бюь'),))
# Parse(word='лдт', tag=OpencorporaTag('UNKN'), normal_form='лдт', score=1.0, methods_stack=((<UnknAnalyzer>, 'лдт'),))
# Parse(word='ки', tag=OpencorporaTag('UNKN'), normal_form='ки', score=1.0, methods_stack=((<UnknAnalyzer>, 'ки'),))
# Parse(word='чно', tag=OpencorporaTag('UNKN'), normal_form='чно', score=1.0, methods_stack=((<UnknAnalyzer>, 'чно'),))
# Parse(word='ёк', tag=OpencorporaTag('UNKN'), normal_form='ёк', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёк'),))
# Parse(word='лос', tag=OpencorporaTag('UNKN'), normal_form='лос', score=1.0, methods_stack=((<UnknAnalyzer>, 'лос'),))
# Parse(word='ё', tag=OpencorporaTag('UNKN'), normal_form='ё', score=1.0, methods_stack=((<UnknAnalyzer>, 'ё'),))
# Parse(word='сол', tag=OpencorporaTag('UNKN'), normal_form='сол', score=1.0, methods_stack=((<UnknAnalyzer>, 'сол'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='р', tag=OpencorporaTag('UNKN'), normal_form='р', score=1.0, methods_stack=((<UnknAnalyzer>, 'р'),))
# Parse(word='р', tag=OpencorporaTag('UNKN'), normal_form='р', score=1.0, methods_stack=((<UnknAnalyzer>, 'р'),))
# Parse(word='вре', tag=OpencorporaTag('UNKN'), normal_form='вре', score=1.0, methods_stack=((<UnknAnalyzer>, 'вре'),))
# Parse(word='мя', tag=OpencorporaTag('UNKN'), normal_form='мя', score=1.0, methods_stack=((<UnknAnalyzer>, 'мя'),))
# Parse(word='ся', tag=OpencorporaTag('UNKN'), normal_form='ся', score=1.0, methods_stack=((<UnknAnalyzer>, 'ся'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='щок', tag=OpencorporaTag('UNKN'), normal_form='щок', score=1.0, methods_stack=((<UnknAnalyzer>, 'щок'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='аяо', tag=OpencorporaTag('UNKN'), normal_form='аяо', score=1.0, methods_stack=((<UnknAnalyzer>, 'аяо'),))
# Parse(word='ие', tag=OpencorporaTag('UNKN'), normal_form='ие', score=1.0, methods_stack=((<UnknAnalyzer>, 'ие'),))
# Parse(word='уаэ', tag=OpencorporaTag('UNKN'), normal_form='уаэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'уаэ'),))
# Parse(word='тра', tag=OpencorporaTag('UNKN'), normal_form='тра', score=1.0, methods_stack=((<UnknAnalyzer>, 'тра'),))
# Parse(word='ла', tag=OpencorporaTag('UNKN'), normal_form='ла', score=1.0, methods_stack=((<UnknAnalyzer>, 'ла'),))
# Parse(word='ла', tag=OpencorporaTag('UNKN'), normal_form='ла', score=1.0, methods_stack=((<UnknAnalyzer>, 'ла'),))
# Parse(word='ви', tag=OpencorporaTag('UNKN'), normal_form='ви', score=1.0, methods_stack=((<UnknAnalyzer>, 'ви'),))
# Parse(word='ро', tag=OpencorporaTag('UNKN'), normal_form='ро', score=1.0, methods_stack=((<UnknAnalyzer>, 'ро'),))
# Parse(word='ный', tag=OpencorporaTag('UNKN'), normal_form='ный', score=1.0, methods_stack=((<UnknAnalyzer>, 'ный'),))
# Parse(word='бэд', tag=OpencorporaTag('UNKN'), normal_form='бэд', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэд'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='пед', tag=OpencorporaTag('UNKN'), normal_form='пед', score=1.0, methods_stack=((<UnknAnalyzer>, 'пед'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='нью', tag=OpencorporaTag('UNKN'), normal_form='нью', score=1.0, methods_stack=((<UnknAnalyzer>, 'нью'),))
# Parse(word='ёрк', tag=OpencorporaTag('UNKN'), normal_form='ёрк', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёрк'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='опа', tag=OpencorporaTag('UNKN'), normal_form='опа', score=1.0, methods_stack=((<UnknAnalyzer>, 'опа'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='эл', tag=OpencorporaTag('UNKN'), normal_form='эл', score=1.0, methods_stack=((<UnknAnalyzer>, 'эл'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='замуш', tag=OpencorporaTag('UNKN'), normal_form='замуш', score=1.0, methods_stack=((<UnknAnalyzer>, 'муш'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='дерсу', tag=OpencorporaTag('UNKN'), normal_form='дерсу', score=1.0, methods_stack=((<UnknAnalyzer>, 'рсу'), (<KnownPrefixAnalyzer>, 'де')))
# Parse(word='еш', tag=OpencorporaTag('UNKN'), normal_form='еш', score=1.0, methods_stack=((<UnknAnalyzer>, 'еш'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='ень', tag=OpencorporaTag('UNKN'), normal_form='ень', score=1.0, methods_stack=((<UnknAnalyzer>, 'ень'),))
# Parse(word='ик', tag=OpencorporaTag('UNKN'), normal_form='ик', score=1.0, methods_stack=((<UnknAnalyzer>, 'ик'),))
# Parse(word='сос', tag=OpencorporaTag('UNKN'), normal_form='сос', score=1.0, methods_stack=((<UnknAnalyzer>, 'сос'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='доч', tag=OpencorporaTag('UNKN'), normal_form='доч', score=1.0, methods_stack=((<UnknAnalyzer>, 'доч'),))
# Parse(word='дыщ', tag=OpencorporaTag('UNKN'), normal_form='дыщ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дыщ'),))
# Parse(word='шай', tag=OpencorporaTag('UNKN'), normal_form='шай', score=1.0, methods_stack=((<UnknAnalyzer>, 'шай'),))
# Parse(word='орк', tag=OpencorporaTag('UNKN'), normal_form='орк', score=1.0, methods_stack=((<UnknAnalyzer>, 'орк'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='ле', tag=OpencorporaTag('UNKN'), normal_form='ле', score=1.0, methods_stack=((<UnknAnalyzer>, 'ле'),))
# Parse(word='дзю', tag=OpencorporaTag('UNKN'), normal_form='дзю', score=1.0, methods_stack=((<UnknAnalyzer>, 'дзю'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='аху', tag=OpencorporaTag('UNKN'), normal_form='аху', score=1.0, methods_stack=((<UnknAnalyzer>, 'аху'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='аха', tag=OpencorporaTag('UNKN'), normal_form='аха', score=1.0, methods_stack=((<UnknAnalyzer>, 'аха'),))
# Parse(word='панияд', tag=OpencorporaTag('UNKN'), normal_form='панияд', score=1.0, methods_stack=((<UnknAnalyzer>, 'ияд'), (<KnownPrefixAnalyzer>, 'пан')))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='еби', tag=OpencorporaTag('UNKN'), normal_form='еби', score=1.0, methods_stack=((<UnknAnalyzer>, 'еби'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='резун', tag=OpencorporaTag('UNKN'), normal_form='резун', score=1.0, methods_stack=((<UnknAnalyzer>, 'зун'), (<KnownPrefixAnalyzer>, 'ре')))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='шоп', tag=OpencorporaTag('UNKN'), normal_form='шоп', score=1.0, methods_stack=((<UnknAnalyzer>, 'шоп'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='ури', tag=OpencorporaTag('UNKN'), normal_form='ури', score=1.0, methods_stack=((<UnknAnalyzer>, 'ури'),))
# Parse(word='кэ', tag=OpencorporaTag('UNKN'), normal_form='кэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'кэ'),))
# Parse(word='мэ', tag=OpencorporaTag('UNKN'), normal_form='мэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'мэ'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ма', tag=OpencorporaTag('UNKN'), normal_form='ма', score=1.0, methods_stack=((<UnknAnalyzer>, 'ма'),))
# Parse(word='ви', tag=OpencorporaTag('UNKN'), normal_form='ви', score=1.0, methods_stack=((<UnknAnalyzer>, 'ви'),))
# Parse(word='жу', tag=OpencorporaTag('UNKN'), normal_form='жу', score=1.0, methods_stack=((<UnknAnalyzer>, 'жу'),))
# Parse(word='дру', tag=OpencorporaTag('UNKN'), normal_form='дру', score=1.0, methods_stack=((<UnknAnalyzer>, 'дру'),))
# Parse(word='сде', tag=OpencorporaTag('UNKN'), normal_form='сде', score=1.0, methods_stack=((<UnknAnalyzer>, 'сде'),))
# Parse(word='хле', tag=OpencorporaTag('UNKN'), normal_form='хле', score=1.0, methods_stack=((<UnknAnalyzer>, 'хле'),))
# Parse(word='кра', tag=OpencorporaTag('UNKN'), normal_form='кра', score=1.0, methods_stack=((<UnknAnalyzer>, 'кра'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='еше', tag=OpencorporaTag('UNKN'), normal_form='еше', score=1.0, methods_stack=((<UnknAnalyzer>, 'еше'),))
# Parse(word='сус', tag=OpencorporaTag('UNKN'), normal_form='сус', score=1.0, methods_stack=((<UnknAnalyzer>, 'сус'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ри', tag=OpencorporaTag('UNKN'), normal_form='ри', score=1.0, methods_stack=((<UnknAnalyzer>, 'ри'),))
# Parse(word='ру', tag=OpencorporaTag('UNKN'), normal_form='ру', score=1.0, methods_stack=((<UnknAnalyzer>, 'ру'),))
# Parse(word='ра', tag=OpencorporaTag('UNKN'), normal_form='ра', score=1.0, methods_stack=((<UnknAnalyzer>, 'ра'),))
# Parse(word='шо', tag=OpencorporaTag('UNKN'), normal_form='шо', score=1.0, methods_stack=((<UnknAnalyzer>, 'шо'),))
# Parse(word='щяс', tag=OpencorporaTag('UNKN'), normal_form='щяс', score=1.0, methods_stack=((<UnknAnalyzer>, 'щяс'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='гда', tag=OpencorporaTag('UNKN'), normal_form='гда', score=1.0, methods_stack=((<UnknAnalyzer>, 'гда'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='евр', tag=OpencorporaTag('UNKN'), normal_form='евр', score=1.0, methods_stack=((<UnknAnalyzer>, 'евр'),))
# Parse(word='пю', tag=OpencorporaTag('UNKN'), normal_form='пю', score=1.0, methods_stack=((<UnknAnalyzer>, 'пю'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='постоян', tag=OpencorporaTag('UNKN'), normal_form='постоян', score=1.0, methods_stack=((<UnknAnalyzer>, 'оян'), (<KnownPrefixAnalyzer>, 'пост')))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='кэ', tag=OpencorporaTag('UNKN'), normal_form='кэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'кэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ё', tag=OpencorporaTag('UNKN'), normal_form='ё', score=1.0, methods_stack=((<UnknAnalyzer>, 'ё'),))
# Parse(word='жэ', tag=OpencorporaTag('UNKN'), normal_form='жэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'жэ'),))
# Parse(word='ред', tag=OpencorporaTag('UNKN'), normal_form='ред', score=1.0, methods_stack=((<UnknAnalyzer>, 'ред'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='ок', tag=OpencorporaTag('UNKN'), normal_form='ок', score=1.0, methods_stack=((<UnknAnalyzer>, 'ок'),))
# Parse(word='реч', tag=OpencorporaTag('UNKN'), normal_form='реч', score=1.0, methods_stack=((<UnknAnalyzer>, 'реч'),))
# Parse(word='оф', tag=OpencorporaTag('UNKN'), normal_form='оф', score=1.0, methods_stack=((<UnknAnalyzer>, 'оф'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='небесица', tag=OpencorporaTag('UNKN'), normal_form='небесица', score=1.0, methods_stack=((<UnknAnalyzer>, 'ица'), (<KnownPrefixAnalyzer>, 'бес'), (<KnownPrefixAnalyzer>, 'не')))
# Parse(word='бесица', tag=OpencorporaTag('UNKN'), normal_form='бесица', score=1.0, methods_stack=((<UnknAnalyzer>, 'ица'), (<KnownPrefixAnalyzer>, 'бес')))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='ноу', tag=OpencorporaTag('UNKN'), normal_form='ноу', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноу'),))
# Parse(word='ноу', tag=OpencorporaTag('UNKN'), normal_form='ноу', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноу'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='бла', tag=OpencorporaTag('UNKN'), normal_form='бла', score=1.0, methods_stack=((<UnknAnalyzer>, 'бла'),))
# Parse(word='хде', tag=OpencorporaTag('UNKN'), normal_form='хде', score=1.0, methods_stack=((<UnknAnalyzer>, 'хде'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='вип', tag=OpencorporaTag('UNKN'), normal_form='вип', score=1.0, methods_stack=((<UnknAnalyzer>, 'вип'),))
# Parse(word='мощ', tag=OpencorporaTag('UNKN'), normal_form='мощ', score=1.0, methods_stack=((<UnknAnalyzer>, 'мощ'),))
# Parse(word='хох', tag=OpencorporaTag('UNKN'), normal_form='хох', score=1.0, methods_stack=((<UnknAnalyzer>, 'хох'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='ло', tag=OpencorporaTag('UNKN'), normal_form='ло', score=1.0, methods_stack=((<UnknAnalyzer>, 'ло'),))
# Parse(word='ло', tag=OpencorporaTag('UNKN'), normal_form='ло', score=1.0, methods_stack=((<UnknAnalyzer>, 'ло'),))
# Parse(word='ло', tag=OpencorporaTag('UNKN'), normal_form='ло', score=1.0, methods_stack=((<UnknAnalyzer>, 'ло'),))
# Parse(word='ло', tag=OpencorporaTag('UNKN'), normal_form='ло', score=1.0, methods_stack=((<UnknAnalyzer>, 'ло'),))
# Parse(word='ло', tag=OpencorporaTag('UNKN'), normal_form='ло', score=1.0, methods_stack=((<UnknAnalyzer>, 'ло'),))
# Parse(word='чук', tag=OpencorporaTag('UNKN'), normal_form='чук', score=1.0, methods_stack=((<UnknAnalyzer>, 'чук'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='зажог', tag=OpencorporaTag('UNKN'), normal_form='зажог', score=1.0, methods_stack=((<UnknAnalyzer>, 'жог'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='лю', tag=OpencorporaTag('UNKN'), normal_form='лю', score=1.0, methods_stack=((<UnknAnalyzer>, 'лю'),))
# Parse(word='жды', tag=OpencorporaTag('UNKN'), normal_form='жды', score=1.0, methods_stack=((<UnknAnalyzer>, 'жды'),))
# Parse(word='жды', tag=OpencorporaTag('UNKN'), normal_form='жды', score=1.0, methods_stack=((<UnknAnalyzer>, 'жды'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='лю', tag=OpencorporaTag('UNKN'), normal_form='лю', score=1.0, methods_stack=((<UnknAnalyzer>, 'лю'),))
# Parse(word='ро', tag=OpencorporaTag('UNKN'), normal_form='ро', score=1.0, methods_stack=((<UnknAnalyzer>, 'ро'),))
# Parse(word='ет', tag=OpencorporaTag('UNKN'), normal_form='ет', score=1.0, methods_stack=((<UnknAnalyzer>, 'ет'),))
# Parse(word='кул', tag=OpencorporaTag('UNKN'), normal_form='кул', score=1.0, methods_stack=((<UnknAnalyzer>, 'кул'),))
# Parse(word='лу', tag=OpencorporaTag('UNKN'), normal_form='лу', score=1.0, methods_stack=((<UnknAnalyzer>, 'лу'),))
# Parse(word='езв', tag=OpencorporaTag('UNKN'), normal_form='езв', score=1.0, methods_stack=((<UnknAnalyzer>, 'езв'),))
# Parse(word='ёзд', tag=OpencorporaTag('UNKN'), normal_form='ёзд', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёзд'),))
# Parse(word='оч', tag=OpencorporaTag('UNKN'), normal_form='оч', score=1.0, methods_stack=((<UnknAnalyzer>, 'оч'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='бл', tag=OpencorporaTag('UNKN'), normal_form='бл', score=1.0, methods_stack=((<UnknAnalyzer>, 'бл'),))
# Parse(word='сос', tag=OpencorporaTag('UNKN'), normal_form='сос', score=1.0, methods_stack=((<UnknAnalyzer>, 'сос'),))
# Parse(word='реч', tag=OpencorporaTag('UNKN'), normal_form='реч', score=1.0, methods_stack=((<UnknAnalyzer>, 'реч'),))
# Parse(word='ок', tag=OpencorporaTag('UNKN'), normal_form='ок', score=1.0, methods_stack=((<UnknAnalyzer>, 'ок'),))
# Parse(word='тео', tag=OpencorporaTag('UNKN'), normal_form='тео', score=1.0, methods_stack=((<UnknAnalyzer>, 'тео'),))
# Parse(word='убо', tag=OpencorporaTag('UNKN'), normal_form='убо', score=1.0, methods_stack=((<UnknAnalyzer>, 'убо'),))
# Parse(word='ки', tag=OpencorporaTag('UNKN'), normal_form='ки', score=1.0, methods_stack=((<UnknAnalyzer>, 'ки'),))
# Parse(word='бьё', tag=OpencorporaTag('UNKN'), normal_form='бьё', score=1.0, methods_stack=((<UnknAnalyzer>, 'бьё'),))
# Parse(word='тмо', tag=OpencorporaTag('UNKN'), normal_form='тмо', score=1.0, methods_stack=((<UnknAnalyzer>, 'тмо'),))
# Parse(word='ме', tag=OpencorporaTag('UNKN'), normal_form='ме', score=1.0, methods_stack=((<UnknAnalyzer>, 'ме'),))
# Parse(word='зя', tag=OpencorporaTag('UNKN'), normal_form='зя', score=1.0, methods_stack=((<UnknAnalyzer>, 'зя'),))
# Parse(word='ког', tag=OpencorporaTag('UNKN'), normal_form='ког', score=1.0, methods_stack=((<UnknAnalyzer>, 'ког'),))
# Parse(word='каб', tag=OpencorporaTag('UNKN'), normal_form='каб', score=1.0, methods_stack=((<UnknAnalyzer>, 'каб'),))
# Parse(word='постить', tag=OpencorporaTag('UNKN'), normal_form='постить', score=1.0, methods_stack=((<UnknAnalyzer>, 'ить'), (<KnownPrefixAnalyzer>, 'пост')))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='жеж', tag=OpencorporaTag('UNKN'), normal_form='жеж', score=1.0, methods_stack=((<UnknAnalyzer>, 'жеж'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='нэ', tag=OpencorporaTag('UNKN'), normal_form='нэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'нэ'),))
# Parse(word='нэ', tag=OpencorporaTag('UNKN'), normal_form='нэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'нэ'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='мыш', tag=OpencorporaTag('UNKN'), normal_form='мыш', score=1.0, methods_stack=((<UnknAnalyzer>, 'мыш'),))
# Parse(word='денех', tag=OpencorporaTag('UNKN'), normal_form='денех', score=1.0, methods_stack=((<UnknAnalyzer>, 'нех'), (<KnownPrefixAnalyzer>, 'де')))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='двухуий', tag=OpencorporaTag('UNKN'), normal_form='двухуий', score=0.5, methods_stack=((<UnknAnalyzer>, 'уий'), (<KnownPrefixAnalyzer>, 'двух')))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ци', tag=OpencorporaTag('UNKN'), normal_form='ци', score=1.0, methods_stack=((<UnknAnalyzer>, 'ци'),))
# Parse(word='нах', tag=OpencorporaTag('UNKN'), normal_form='нах', score=1.0, methods_stack=((<UnknAnalyzer>, 'нах'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='доч', tag=OpencorporaTag('UNKN'), normal_form='доч', score=1.0, methods_stack=((<UnknAnalyzer>, 'доч'),))
# Parse(word='пэо', tag=OpencorporaTag('UNKN'), normal_form='пэо', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэо'),))
# Parse(word='жы', tag=OpencorporaTag('UNKN'), normal_form='жы', score=1.0, methods_stack=((<UnknAnalyzer>, 'жы'),))
# Parse(word='шы', tag=OpencorporaTag('UNKN'), normal_form='шы', score=1.0, methods_stack=((<UnknAnalyzer>, 'шы'),))
# Parse(word='ви', tag=OpencorporaTag('UNKN'), normal_form='ви', score=1.0, methods_stack=((<UnknAnalyzer>, 'ви'),))
# Parse(word='нью', tag=OpencorporaTag('UNKN'), normal_form='нью', score=1.0, methods_stack=((<UnknAnalyzer>, 'нью'),))
# Parse(word='юго', tag=OpencorporaTag('UNKN'), normal_form='юго', score=1.0, methods_stack=((<UnknAnalyzer>, 'юго'),))
# Parse(word='ци', tag=OpencorporaTag('UNKN'), normal_form='ци', score=1.0, methods_stack=((<UnknAnalyzer>, 'ци'),))
# Parse(word='упс', tag=OpencorporaTag('UNKN'), normal_form='упс', score=1.0, methods_stack=((<UnknAnalyzer>, 'упс'),))
# Parse(word='шос', tag=OpencorporaTag('UNKN'), normal_form='шос', score=1.0, methods_stack=((<UnknAnalyzer>, 'шос'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='цэ', tag=OpencorporaTag('UNKN'), normal_form='цэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'цэ'),))
# Parse(word='жон', tag=OpencorporaTag('UNKN'), normal_form='жон', score=1.0, methods_stack=((<UnknAnalyzer>, 'жон'),))
# Parse(word='юэ', tag=OpencorporaTag('UNKN'), normal_form='юэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'юэ'),))
# Parse(word='энд', tag=OpencorporaTag('UNKN'), normal_form='энд', score=1.0, methods_stack=((<UnknAnalyzer>, 'энд'),))
# Parse(word='сос', tag=OpencorporaTag('UNKN'), normal_form='сос', score=1.0, methods_stack=((<UnknAnalyzer>, 'сос'),))
# Parse(word='ок', tag=OpencorporaTag('UNKN'), normal_form='ок', score=1.0, methods_stack=((<UnknAnalyzer>, 'ок'),))
# Parse(word='бад', tag=OpencorporaTag('UNKN'), normal_form='бад', score=1.0, methods_stack=((<UnknAnalyzer>, 'бад'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='рио', tag=OpencorporaTag('UNKN'), normal_form='рио', score=1.0, methods_stack=((<UnknAnalyzer>, 'рио'),))
# Parse(word='кв', tag=OpencorporaTag('UNKN'), normal_form='кв', score=1.0, methods_stack=((<UnknAnalyzer>, 'кв'),))
# Parse(word='жы', tag=OpencorporaTag('UNKN'), normal_form='жы', score=1.0, methods_stack=((<UnknAnalyzer>, 'жы'),))
# Parse(word='шы', tag=OpencorporaTag('UNKN'), normal_form='шы', score=1.0, methods_stack=((<UnknAnalyzer>, 'шы'),))
# Parse(word='мун', tag=OpencorporaTag('UNKN'), normal_form='мун', score=1.0, methods_stack=((<UnknAnalyzer>, 'мун'),))
# Parse(word='бэк', tag=OpencorporaTag('UNKN'), normal_form='бэк', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэк'),))
# Parse(word='ёб', tag=OpencorporaTag('UNKN'), normal_form='ёб', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёб'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='гоа', tag=OpencorporaTag('UNKN'), normal_form='гоа', score=1.0, methods_stack=((<UnknAnalyzer>, 'гоа'),))
# Parse(word='юго', tag=OpencorporaTag('UNKN'), normal_form='юго', score=1.0, methods_stack=((<UnknAnalyzer>, 'юго'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='ону', tag=OpencorporaTag('UNKN'), normal_form='ону', score=1.0, methods_stack=((<UnknAnalyzer>, 'ону'),))
# Parse(word='уе', tag=OpencorporaTag('UNKN'), normal_form='уе', score=1.0, methods_stack=((<UnknAnalyzer>, 'уе'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ё', tag=OpencorporaTag('UNKN'), normal_form='ё', score=1.0, methods_stack=((<UnknAnalyzer>, 'ё'),))
# Parse(word='ща', tag=OpencorporaTag('UNKN'), normal_form='ща', score=1.0, methods_stack=((<UnknAnalyzer>, 'ща'),))
# Parse(word='нью', tag=OpencorporaTag('UNKN'), normal_form='нью', score=1.0, methods_stack=((<UnknAnalyzer>, 'нью'),))
# Parse(word='вэ', tag=OpencorporaTag('UNKN'), normal_form='вэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'вэ'),))
# Parse(word='щаз', tag=OpencorporaTag('UNKN'), normal_form='щаз', score=1.0, methods_stack=((<UnknAnalyzer>, 'щаз'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='аху', tag=OpencorporaTag('UNKN'), normal_form='аху', score=1.0, methods_stack=((<UnknAnalyzer>, 'аху'),))
# Parse(word='нео', tag=OpencorporaTag('UNKN'), normal_form='нео', score=1.0, methods_stack=((<UnknAnalyzer>, 'нео'),))
# Parse(word='аху', tag=OpencorporaTag('UNKN'), normal_form='аху', score=1.0, methods_stack=((<UnknAnalyzer>, 'аху'),))
# Parse(word='нью', tag=OpencorporaTag('UNKN'), normal_form='нью', score=1.0, methods_stack=((<UnknAnalyzer>, 'нью'),))
# Parse(word='ор', tag=OpencorporaTag('UNKN'), normal_form='ор', score=1.0, methods_stack=((<UnknAnalyzer>, 'ор'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='р', tag=OpencorporaTag('UNKN'), normal_form='р', score=1.0, methods_stack=((<UnknAnalyzer>, 'р'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='пирожек', tag=OpencorporaTag('UNKN'), normal_form='пирожек', score=1.0, methods_stack=((<UnknAnalyzer>, 'жек'), (<KnownPrefixAnalyzer>, 'пиро')))
# Parse(word='ща', tag=OpencorporaTag('UNKN'), normal_form='ща', score=1.0, methods_stack=((<UnknAnalyzer>, 'ща'),))
# Parse(word='фих', tag=OpencorporaTag('UNKN'), normal_form='фих', score=1.0, methods_stack=((<UnknAnalyzer>, 'фих'),))
# Parse(word='дип', tag=OpencorporaTag('UNKN'), normal_form='дип', score=1.0, methods_stack=((<UnknAnalyzer>, 'дип'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='пэ', tag=OpencorporaTag('UNKN'), normal_form='пэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'пэ'),))
# Parse(word='зэ', tag=OpencorporaTag('UNKN'), normal_form='зэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'зэ'),))
# Parse(word='энд', tag=OpencorporaTag('UNKN'), normal_form='энд', score=1.0, methods_stack=((<UnknAnalyzer>, 'энд'),))
# Parse(word='зэм', tag=OpencorporaTag('UNKN'), normal_form='зэм', score=1.0, methods_stack=((<UnknAnalyzer>, 'зэм'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='эл', tag=OpencorporaTag('UNKN'), normal_form='эл', score=1.0, methods_stack=((<UnknAnalyzer>, 'эл'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='хто', tag=OpencorporaTag('UNKN'), normal_form='хто', score=1.0, methods_stack=((<UnknAnalyzer>, 'хто'),))
# Parse(word='йво', tag=OpencorporaTag('UNKN'), normal_form='йво', score=1.0, methods_stack=((<UnknAnalyzer>, 'йво'),))
# Parse(word='хой', tag=OpencorporaTag('UNKN'), normal_form='хой', score=1.0, methods_stack=((<UnknAnalyzer>, 'хой'),))
# Parse(word='зэ', tag=OpencorporaTag('UNKN'), normal_form='зэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'зэ'),))
# Parse(word='дип', tag=OpencorporaTag('UNKN'), normal_form='дип', score=1.0, methods_stack=((<UnknAnalyzer>, 'дип'),))
# Parse(word='хип', tag=OpencorporaTag('UNKN'), normal_form='хип', score=1.0, methods_stack=((<UnknAnalyzer>, 'хип'),))
# Parse(word='сай', tag=OpencorporaTag('UNKN'), normal_form='сай', score=1.0, methods_stack=((<UnknAnalyzer>, 'сай'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='жэ', tag=OpencorporaTag('UNKN'), normal_form='жэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'жэ'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='ноч', tag=OpencorporaTag('UNKN'), normal_form='ноч', score=1.0, methods_stack=((<UnknAnalyzer>, 'ноч'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='радиохэд', tag=OpencorporaTag('UNKN'), normal_form='радиохэд', score=1.0, methods_stack=((<UnknAnalyzer>, 'хэд'), (<KnownPrefixAnalyzer>, 'радио')))
# ...
# Parse(word='аху', tag=OpencorporaTag('UNKN'), normal_form='аху', score=1.0, methods_stack=((<UnknAnalyzer>, 'аху'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='йож', tag=OpencorporaTag('UNKN'), normal_form='йож', score=1.0, methods_stack=((<UnknAnalyzer>, 'йож'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='дэс', tag=OpencorporaTag('UNKN'), normal_form='дэс', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэс'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='жо', tag=OpencorporaTag('UNKN'), normal_form='жо', score=1.0, methods_stack=((<UnknAnalyzer>, 'жо'),))
# Parse(word='вип', tag=OpencorporaTag('UNKN'), normal_form='вип', score=1.0, methods_stack=((<UnknAnalyzer>, 'вип'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='еси', tag=OpencorporaTag('UNKN'), normal_form='еси', score=1.0, methods_stack=((<UnknAnalyzer>, 'еси'),))
# Parse(word='ёг', tag=OpencorporaTag('UNKN'), normal_form='ёг', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёг'),))
# Parse(word='нео', tag=OpencorporaTag('UNKN'), normal_form='нео', score=1.0, methods_stack=((<UnknAnalyzer>, 'нео'),))
# Parse(word='ща', tag=OpencorporaTag('UNKN'), normal_form='ща', score=1.0, methods_stack=((<UnknAnalyzer>, 'ща'),))
# Parse(word='зай', tag=OpencorporaTag('UNKN'), normal_form='зай', score=1.0, methods_stack=((<UnknAnalyzer>, 'зай'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='зачот', tag=OpencorporaTag('UNKN'), normal_form='зачот', score=1.0, methods_stack=((<UnknAnalyzer>, 'чот'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='шён', tag=OpencorporaTag('UNKN'), normal_form='шён', score=1.0, methods_stack=((<UnknAnalyzer>, 'шён'),))
# Parse(word='йа', tag=OpencorporaTag('UNKN'), normal_form='йа', score=1.0, methods_stack=((<UnknAnalyzer>, 'йа'),))
# Parse(word='недоёба', tag=OpencorporaTag('UNKN'), normal_form='недоёба', score=1.0, methods_stack=((<UnknAnalyzer>, 'ёба'), (<KnownPrefixAnalyzer>, 'недо')))
# Parse(word='жэ', tag=OpencorporaTag('UNKN'), normal_form='жэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'жэ'),))
# Parse(word='чмо', tag=OpencorporaTag('UNKN'), normal_form='чмо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чмо'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='гоа', tag=OpencorporaTag('UNKN'), normal_form='гоа', score=1.0, methods_stack=((<UnknAnalyzer>, 'гоа'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ын', tag=OpencorporaTag('UNKN'), normal_form='ын', score=1.0, methods_stack=((<UnknAnalyzer>, 'ын'),))
# Parse(word='лиш', tag=OpencorporaTag('UNKN'), normal_form='лиш', score=1.0, methods_stack=((<UnknAnalyzer>, 'лиш'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='р', tag=OpencorporaTag('UNKN'), normal_form='р', score=1.0, methods_stack=((<UnknAnalyzer>, 'р'),))
# Parse(word='лэй', tag=OpencorporaTag('UNKN'), normal_form='лэй', score=1.0, methods_stack=((<UnknAnalyzer>, 'лэй'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='спа', tag=OpencorporaTag('UNKN'), normal_form='спа', score=1.0, methods_stack=((<UnknAnalyzer>, 'спа'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='дожик', tag=OpencorporaTag('UNKN'), normal_form='дожик', score=1.0, methods_stack=((<UnknAnalyzer>, 'жик'), (<KnownPrefixAnalyzer>, 'до')))
# Parse(word='жок', tag=OpencorporaTag('UNKN'), normal_form='жок', score=1.0, methods_stack=((<UnknAnalyzer>, 'жок'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='ду', tag=OpencorporaTag('UNKN'), normal_form='ду', score=1.0, methods_stack=((<UnknAnalyzer>, 'ду'),))
# Parse(word='чом', tag=OpencorporaTag('UNKN'), normal_form='чом', score=1.0, methods_stack=((<UnknAnalyzer>, 'чом'),))
# Parse(word='тыц', tag=OpencorporaTag('UNKN'), normal_form='тыц', score=1.0, methods_stack=((<UnknAnalyzer>, 'тыц'),))
# Parse(word='тыц', tag=OpencorporaTag('UNKN'), normal_form='тыц', score=1.0, methods_stack=((<UnknAnalyzer>, 'тыц'),))
# Parse(word='тыц', tag=OpencorporaTag('UNKN'), normal_form='тыц', score=1.0, methods_stack=((<UnknAnalyzer>, 'тыц'),))
# Parse(word='тыц', tag=OpencorporaTag('UNKN'), normal_form='тыц', score=1.0, methods_stack=((<UnknAnalyzer>, 'тыц'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='общемто', tag=OpencorporaTag('UNKN'), normal_form='общемто', score=1.0, methods_stack=((<UnknAnalyzer>, 'мто'), (<KnownPrefixAnalyzer>, 'обще')))
# Parse(word='ё', tag=OpencorporaTag('UNKN'), normal_form='ё', score=1.0, methods_stack=((<UnknAnalyzer>, 'ё'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='дэ', tag=OpencorporaTag('UNKN'), normal_form='дэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'дэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='йож', tag=OpencorporaTag('UNKN'), normal_form='йож', score=1.0, methods_stack=((<UnknAnalyzer>, 'йож'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='тум', tag=OpencorporaTag('UNKN'), normal_form='тум', score=1.0, methods_stack=((<UnknAnalyzer>, 'тум'),))
# Parse(word='ся', tag=OpencorporaTag('UNKN'), normal_form='ся', score=1.0, methods_stack=((<UnknAnalyzer>, 'ся'),))
# Parse(word='бох', tag=OpencorporaTag('UNKN'), normal_form='бох', score=1.0, methods_stack=((<UnknAnalyzer>, 'бох'),))
# Parse(word='вэ', tag=OpencorporaTag('UNKN'), normal_form='вэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'вэ'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='чук', tag=OpencorporaTag('UNKN'), normal_form='чук', score=1.0, methods_stack=((<UnknAnalyzer>, 'чук'),))
# Parse(word='био', tag=OpencorporaTag('UNKN'), normal_form='био', score=1.0, methods_stack=((<UnknAnalyzer>, 'био'),))
# Parse(word='жэ', tag=OpencorporaTag('UNKN'), normal_form='жэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'жэ'),))
# Parse(word='кэ', tag=OpencorporaTag('UNKN'), normal_form='кэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'кэ'),))
# Parse(word='ещо', tag=OpencorporaTag('UNKN'), normal_form='ещо', score=1.0, methods_stack=((<UnknAnalyzer>, 'ещо'),))
# Parse(word='йу', tag=OpencorporaTag('UNKN'), normal_form='йу', score=1.0, methods_stack=((<UnknAnalyzer>, 'йу'),))
# Parse(word='эл', tag=OpencorporaTag('UNKN'), normal_form='эл', score=1.0, methods_stack=((<UnknAnalyzer>, 'эл'),))
# Parse(word='ла', tag=OpencorporaTag('UNKN'), normal_form='ла', score=1.0, methods_stack=((<UnknAnalyzer>, 'ла'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='жэ', tag=OpencorporaTag('UNKN'), normal_form='жэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'жэ'),))
# Parse(word='олу', tag=OpencorporaTag('UNKN'), normal_form='олу', score=1.0, methods_stack=((<UnknAnalyzer>, 'олу'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='яб', tag=OpencorporaTag('UNKN'), normal_form='яб', score=1.0, methods_stack=((<UnknAnalyzer>, 'яб'),))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='ш', tag=OpencorporaTag('UNKN'), normal_form='ш', score=1.0, methods_stack=((<UnknAnalyzer>, 'ш'),))
# Parse(word='заебу', tag=OpencorporaTag('UNKN'), normal_form='заебу', score=1.0, methods_stack=((<UnknAnalyzer>, 'ебу'), (<KnownPrefixAnalyzer>, 'за')))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='кей', tag=OpencorporaTag('UNKN'), normal_form='кей', score=1.0, methods_stack=((<UnknAnalyzer>, 'кей'),))
# Parse(word='фер', tag=OpencorporaTag('UNKN'), normal_form='фер', score=1.0, methods_stack=((<UnknAnalyzer>, 'фер'),))
# Parse(word='тэ', tag=OpencorporaTag('UNKN'), normal_form='тэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'тэ'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='дожём', tag=OpencorporaTag('UNKN'), normal_form='дожём', score=1.0, methods_stack=((<UnknAnalyzer>, 'жём'), (<KnownPrefixAnalyzer>, 'до')))
# Parse(word='энд', tag=OpencorporaTag('UNKN'), normal_form='энд', score=1.0, methods_stack=((<UnknAnalyzer>, 'энд'),))
# Parse(word='электронке', tag=OpencorporaTag('UNKN'), normal_form='электронке', score=1.0, methods_stack=((<UnknAnalyzer>, 'нке'), (<KnownPrefixAnalyzer>, 'электро')))
# Parse(word='че', tag=OpencorporaTag('UNKN'), normal_form='че', score=1.0, methods_stack=((<UnknAnalyzer>, 'че'),))
# Parse(word='мэм', tag=OpencorporaTag('UNKN'), normal_form='мэм', score=1.0, methods_stack=((<UnknAnalyzer>, 'мэм'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='самочка', tag=OpencorporaTag('UNKN'), normal_form='самочка', score=1.0, methods_stack=((<UnknAnalyzer>, 'чка'), (<KnownPrefixAnalyzer>, 'само')))
# Parse(word='чо', tag=OpencorporaTag('UNKN'), normal_form='чо', score=1.0, methods_stack=((<UnknAnalyzer>, 'чо'),))
# Parse(word='нал', tag=OpencorporaTag('UNKN'), normal_form='нал', score=1.0, methods_stack=((<UnknAnalyzer>, 'нал'),))
# Parse(word='ка', tag=OpencorporaTag('UNKN'), normal_form='ка', score=1.0, methods_stack=((<UnknAnalyzer>, 'ка'),))
# Parse(word='олл', tag=OpencorporaTag('UNKN'), normal_form='олл', score=1.0, methods_stack=((<UnknAnalyzer>, 'олл'),))
# Parse(word='жо', tag=OpencorporaTag('UNKN'), normal_form='жо', score=1.0, methods_stack=((<UnknAnalyzer>, 'жо'),))
# Parse(word='ху', tag=OpencorporaTag('UNKN'), normal_form='ху', score=1.0, methods_stack=((<UnknAnalyzer>, 'ху'),))
# Parse(word='ху', tag=OpencorporaTag('UNKN'), normal_form='ху', score=1.0, methods_stack=((<UnknAnalyzer>, 'ху'),))
# Parse(word='жо', tag=OpencorporaTag('UNKN'), normal_form='жо', score=1.0, methods_stack=((<UnknAnalyzer>, 'жо'),))
# Parse(word='зе', tag=OpencorporaTag('UNKN'), normal_form='зе', score=1.0, methods_stack=((<UnknAnalyzer>, 'зе'),))
# Parse(word='ру', tag=OpencorporaTag('UNKN'), normal_form='ру', score=1.0, methods_stack=((<UnknAnalyzer>, 'ру'),))
# Parse(word='сру', tag=OpencorporaTag('UNKN'), normal_form='сру', score=1.0, methods_stack=((<UnknAnalyzer>, 'сру'),))
# Parse(word='чё', tag=OpencorporaTag('UNKN'), normal_form='чё', score=1.0, methods_stack=((<UnknAnalyzer>, 'чё'),))
# Parse(word='гуф', tag=OpencorporaTag('UNKN'), normal_form='гуф', score=1.0, methods_stack=((<UnknAnalyzer>, 'гуф'),))
# Parse(word='бэ', tag=OpencorporaTag('UNKN'), normal_form='бэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'бэ'),))
# Parse(word='вэ', tag=OpencorporaTag('UNKN'), normal_form='вэ', score=1.0, methods_stack=((<UnknAnalyzer>, 'вэ'),))
# Parse(word='ол', tag=OpencorporaTag('UNKN'), normal_form='ол', score=1.0, methods_stack=((<UnknAnalyzer>, 'ол'),))
# Parse(word='хав', tag=OpencorporaTag('UNKN'), normal_form='хав', score=1.0, methods_stack=((<UnknAnalyzer>, 'хав'),))
# Parse(word='ю', tag=OpencorporaTag('UNKN'), normal_form='ю', score=1.0, methods_stack=((<UnknAnalyzer>, 'ю'),))
# Parse(word='ё', tag=OpencorporaTag('UNKN'), normal_form='ё', score=1.0, methods_stack=((<UnknAnalyzer>, 'ё'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# Parse(word='мэй', tag=OpencorporaTag('UNKN'), normal_form='мэй', score=1.0, methods_stack=((<UnknAnalyzer>, 'мэй'),))
# 2017-05-08 02:45:12,377 : INFO : loading projection weights from c:/data/ruscorpora_1_300_10.bin.gz
# Parse(word='рёк', tag=OpencorporaTag('UNKN'), normal_form='рёк', score=1.0, methods_stack=((<UnknAnalyzer>, 'рёк'),))
# Parse(word='ево', tag=OpencorporaTag('UNKN'), normal_form='ево', score=1.0, methods_stack=((<UnknAnalyzer>, 'ево'),))
# loading w2v_model...
# 2017-05-08 02:45:21,165 : INFO : loaded (184973, 300) matrix from c:/data/ruscorpora_1_300_10.bin.gz
# word2vec model 'c:/data/ruscorpora_1_300_10.bin.gz' loaded
# model is compiled

# %%
pm.write('poems_model_big.pickle')

# %%
pm.poems = []
pm.read('poems_model_big.pickle')
pm.poems[:10]
# Out:
# reading pickle poems model...
# vectorizing model...
# model is loaded
# ['ребята мне совсем хреново\nдрузьям аркадий говорит\nдрузья качают головами\nи тычут палочкой в нево\n',
#  'придя домой семён наткнулся\nна лужу серной кислоты\nскорее вытирать скорее\nпока к соседям не прожгло\n',
#  'двенадцать сигарет без фильтра\nи ты уже не человек\nа помесь трупа с вертолетом\nвлетающим в густой туман\n',
#  'мы рождены пустым сосудом\nи наполняемся за жизнь\nа иисус рожденный полным\nвсе жизнь тихонько протекал\n',
#  'давай теперь ты будешь кофе\nа я как сахарный песок\nживым мерцающим потоком\nв тебе всецело растворюсь\n',
#  'когда я стал половозрелый\nя встретил девушку одну\nи предъявил ей между прочим\nполовоззрения свои\n',
#  'правительство нелегитимно\nкричит народ на площадях\nно только путин знает правду\nнелегитимен сам народ\n',
#  'в известняке петрова сердца\nзашевелился трилобит\nпо телу гул прошел волною\nкоснулся пяток и затих\n',
#  'я не люблю мужчин с цветами\nони мне причиняют боль\nкогда счастливою походкой\nидут куда то не ко мне\n',
#  'ещё пятнадцать километров\nи ты увидишь океан\nно чтоб эффект был максимальным\nглаза пока не открывай\n']

# %% [markdown]
# ## Load

# %%
from poems_model import PoemsModel

poems_data_file = 'poems_model_big.pickle'
w2v_file = 'c:/data/ruscorpora_1_300_10.bin.gz'
pm = PoemsModel(poems_data_file, w2v_file)
# Out:
# C:\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Slow version of gensim.models.doc2vec is being used
# 2017-05-08 12:16:25,708 : INFO : loading projection weights from c:/data/ruscorpora_1_300_10.bin.gz
# loading w2v_model...
# 2017-05-08 12:16:34,295 : INFO : loaded (184973, 300) matrix from c:/data/ruscorpora_1_300_10.bin.gz
# word2vec model 'c:/data/ruscorpora_1_300_10.bin.gz' loaded
# reading pickle poems model...
# vectorizing model...
# model is loaded

# %%
pm.poems[:10]
# Out:
# ['ребята мне совсем хреново\nдрузьям аркадий говорит\nдрузья качают головами\nи тычут палочкой в нево\n',
#  'придя домой семён наткнулся\nна лужу серной кислоты\nскорее вытирать скорее\nпока к соседям не прожгло\n',
#  'двенадцать сигарет без фильтра\nи ты уже не человек\nа помесь трупа с вертолетом\nвлетающим в густой туман\n',
#  'мы рождены пустым сосудом\nи наполняемся за жизнь\nа иисус рожденный полным\nвсе жизнь тихонько протекал\n',
#  'давай теперь ты будешь кофе\nа я как сахарный песок\nживым мерцающим потоком\nв тебе всецело растворюсь\n',
#  'когда я стал половозрелый\nя встретил девушку одну\nи предъявил ей между прочим\nполовоззрения свои\n',
#  'правительство нелегитимно\nкричит народ на площадях\nно только путин знает правду\nнелегитимен сам народ\n',
#  'в известняке петрова сердца\nзашевелился трилобит\nпо телу гул прошел волною\nкоснулся пяток и затих\n',
#  'я не люблю мужчин с цветами\nони мне причиняют боль\nкогда счастливою походкой\nидут куда то не ко мне\n',
#  'ещё пятнадцать километров\nи ты увидишь океан\nно чтоб эффект был максимальным\nглаза пока не открывай\n']

# %%
# %pprint
# [(poem.replace('\n', ' '), sim) for poem, sim in poems]
# Out:
# Pretty printing has been turned ON

# %%
for poem in pm.similar_poems('творчество киевского мага и мистика', topn=10): 
    print(f'{poem[0]}\t{poem[1]}')
# Out:
# я чёрный маг владею миром
# брюнет высокий тридцать лет
# ищу с фантазией подругу
# чтоб вместе в вечности царить
# 	0.8646383367254595
# там кант вольтер и фридрих ницше
# там жан поль сартр и зигмунд фрейд
# а мы органику листаем
# и в философии дубы
# 	0.833004909321504
# я ненавижу христианство
# буддизм ислам иудаизм
# язычество и джорджа буша
# люблю пельмени с судаком
# 	0.8101591110229492
# святейший патриарх московский
# владыка царь всея руси
# король всех княжеств князь всех вотчин
# мэр губернатор президент
# 	0.7973235147103934
# давай откроем книгу жизни
# в ней интересного полно
# год выпуска тираж издатель
# редактор автор рецензент
# 	0.7830623216913177
# поэт поэтому поэтом
# был назван что писал стихи
# слова не однокоренные
# но смысл они передают
# 	0.7778656868810945
# не обращали ль вы вниманье
# что если человек масон
# то он ученый очень крупный
# поэт политик журналист
# 	0.7745715141296386
# наука жить почти бессильна
# перед искусством умирать
# сказал печально математик
# и разложился в ряд фурье
# 	0.7739194493281941
# геннадий произнёс заклятье
# слюною плюнул колдовской
# и волшебство любви исчезло
# сменившись магией войны
# 	0.7733073234558105
# так по японски живописна
# на огороде бузина
# что дядька в киеве должно быть
# поэт художник и буддист
# 	0.7574903077165105

# %%
for poem in pm.similar_poems('иллюзия', topn=10): 
    print(f'{poem[0]}\t{poem[1]}')
# Out:
# веселье радость безмятежность
# любовь безудержная страсть
# разумность сдержанная похоть
# задумчивость надежда страх
# 	0.298699688911438
# проста как боль легка как правда
# неосязаема как страх
# скучна как мир пуста как память
# твоя несбывшаяся жизнь
# 	0.2587770765631143
# между мирами жизни смерти
# есть грань тончайшая как лист
# основ основа мир двумерный
# рожденья смерти сна и грёз
# 	0.2543415307998657
# нам код коррекции ошибок
# записан в глубину души
# чтоб мы могли картину мира
# из ложных данных извлекать
# 	0.2463622343458551
# сказал нет бога кроме бога
# и пушкин был пророк его
# а то что с детства вам внушали
# все бред обман и опиум
# 	0.24113795204938893
# илье надежда изменила
# один нескромный бросив взгляд
# всё восприятие пространства
# людей и самого себя
# 	0.2411146305129373
# никто давно не верит в сказки
# про бога и грядущий рай
# вот апокалипсис немного
# ещё способен нас увлечь
# 	0.24087915624377793
# быть может небыло олега
# оксана шепчет зульфие
# а был какойнибуть евгений
# мечты гомункулус обман
# 	0.24083236904029803
# давайте верить в справедливость
# как верят в бога в чудеса
# или в какую то другую
# несуществующую хрень
# 	0.23906973819990882
# живя в несовершенном мире
# несовершенный человек
# всю жизнь надеется наивно
# на совершенную любовь
# 	0.23879228222521537
